# %% [markdown]
# # r.scs.runoff
#
# This notebook runs the example from r.scs.runoff's manual page and visualizes the output.
#
# ## Setup
#
# We will be using the NC SPM sample location.

# %%
import os
import json
import subprocess
import sys

# Ask GRASS where its Python packages are.
sys.path.append(
    subprocess.check_output(["grass", "--config", "python_path"], text=True).strip()
)

# Import GRASS packages
import grass.script as gs
import grass.jupyter as gj

# Start GRASS Session
gj.init("~/data/grassdata/nc_basic_spm_grass7/user1")

# %% [markdown]
# ## Create example from the tool's documentation

# %%
r_scs_runoff_input = "elevation"
r_scs_runoff_output = "output"
gs.run_command(
    "r.scs.runoff",
    input=r_scs_runoff_input,
    output=r_scs_runoff_output,
)

# %%
r_scs_runoff_map = gj.Map()
r_scs_runoff_map.d_rast(map=r_scs_runoff_output)
r_scs_runoff_map.show()
