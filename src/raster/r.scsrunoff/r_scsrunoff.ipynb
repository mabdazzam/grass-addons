# %% [markdown]
# # r.scsrunoff
#
# This notebook runs the example from r.scsrunoff's manual page and visualizes the output.
#
# ## Setup
#
# We will be using the NC SPM sample location.

# %%
import os
import json
import subprocess
import sys

# Ask GRASS where its Python packages are.
sys.path.append(
    subprocess.check_output(["grass", "--config", "python_path"], text=True).strip()
)

# Import GRASS packages
import grass.script as gs
import grass.jupyter as gj

# Start GRASS Session
gj.init("~/data/grassdata/nc_basic_spm_grass7/user1")

# %% [markdown]
# ## Create example from the tool's documentation

# %%
r_scsrunoff_input = "elevation"
r_scsrunoff_output = "output"
gs.run_command(
    "r.scsrunoff",
    input=r_scsrunoff_input,
    output=r_scsrunoff_output,
)

# %%
r_scsrunoff_map = gj.Map()
r_scsrunoff_map.d_rast(map=r_scsrunoff_output)
r_scsrunoff_map.show()
